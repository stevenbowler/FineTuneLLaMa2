# %% [markdown]
# <a href="https://colab.research.google.com/github/stevenbowler/FineTuneLLaMa2/blob/master/llama_2_7b_FineTune.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pinecone-io/examples/blob/master/learn/generation/llm-field-guide/llama-2/llama-2-13b-retrievalqa.ipynb) [![Open nbviewer](https://raw.githubusercontent.com/pinecone-io/examples/master/assets/nbviewer-shield.svg)](https://nbviewer.org/github/pinecone-io/examples/blob/master/learn/generation/llm-field-guide/llama-2/llama-2-13b-retrievalqa.ipynb)
#
# # Fine Tune LLaMa 7B model with RAG
#
# SB: 08/12/2023 updated to use 7b LLaMa model, to lower gpu and ram requirements while finetuning a RAG model that includes a very large open source rules and regs document chunked for consumption in a pinecone vector store.
# ---
#
# 🚨 _Note that running this on CPU is sloooow. If running on Google Colab you can avoid this by going to **Runtime > Change runtime type > Hardware accelerator > GPU > GPU type > T4**. This should be included within the free tier of Colab._
#
# ---
#
# We start by doing a `pip install` of all required libraries.

# %%
# !pip install -qU \
  transformers \
  sentence-transformers \
  pinecone-client \
  datasets \
  accelerate \
  einops \
  langchain \
  xformers \
  bitsandbytes \
  pypdf

# %% [markdown]
# ## Initializing the Hugging Face Embedding Pipeline
#
# We begin by initializing the embedding pipeline that will handle the transformation of our docs into vector embeddings. We will use the `sentence-transformers/all-MiniLM-L6-v2` model for embedding.

# %%
from torch import cuda
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

embed_model_id = 'sentence-transformers/all-MiniLM-L6-v2'

device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'

embed_model = HuggingFaceEmbeddings(
    model_name=embed_model_id,
    model_kwargs={'device': device},
    encode_kwargs={'device': device, 'batch_size': 32}
)
# Out:
# Mounted at /content/drive
# ...

# %% [markdown]
# SB: read a pdf into a dataframe using tabula

# %%
# !pip install tabula-py
# import tabula

# # Read PDF into list of DataFrame
# dataframe = tabula.read_pdf("/content/drive/MyDrive/ColabStuff/TMPPMfiles/2023-07-TMPPM.pdf", pages='all')

# # Read remote PDF into list of DataFrame
# #dataframe_2 = tabula.read_pdf("https://github.com/tabulapdf/tabula-java/raw/master/src/test/resources/technology/tabula/arabic.pdf")

# # Convert PDF into CSV file
# #tabula.convert_into("input.pdf", "output.csv", output_format="csv", pages='all')

# dataframe[1001]

# %% [markdown]
# SB: test creating embeddings from the pdf file, later will be done in chunks

# %%
docs = !source /content/drive/MyDrive/ColabStuff/TMPPMfiles/2023-07-TMPPM.pdf


embeddings = embed_model.embed_documents(docs)

print(f"We have {len(embeddings)} doc embeddings, each with "
      f"a dimensionality of {len(embeddings[0])}.")
# Out:
# We have 1 doc embeddings, each with a dimensionality of 384.

# %% [markdown]
# SB: REPLACE, the next 10 steps chunk out the TMHP file set as data variable in place of what was there previously, once chunked out and stored in HuggingFace dataset then can be retrieved directly from HuggingFace, instead of recreating each iteration, so can skip the next 10 steps.

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
from langchain.document_loaders import PyPDFLoader

loader = PyPDFLoader("/content/drive/MyDrive/ColabStuff/TMPPMfiles/2023-07-TMPPM.pdf")
pages = loader.load_and_split()

documents = loader.load()

#split text into chunks
text_splitter  = RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=50)
text_chunks = text_splitter.split_documents(documents)

# %%
pages[51]  # pages[1298]
# Out:
# Document(page_content='SECTION 1: PROVIDER ENROLLMENT AND RESPONSIBILITIES JULY 2023\n39\nCPT ONLY - COPYRIGHT 2022 AMERICAN MEDICAL ASSOCIATION. ALL RIGHTS RESERVED.Providers may request prior authorization fo r home health services by contacting:\nTexas Medicaid & Healthcare Partnership\nHome Health Services\nPO Box 202977\nAustin, TX 78720-2977\n1-800-925-8957\nFax: 1-512-514-4209\n1.7.14.1 Home Health Skilled Nursing and Home Health Aide (HHA) Services Provider \nResponsibilities\nProviders must be a licensed and certified home he alth agency, enrolled in Texas Medicaid, and must \ncomply with all applicable federal, state, and local laws and regulations and Texas Medicaid policies and \nprocedures. All providers must maintain written policies and procedures:\n• That meet the standards of the Texas Family Code , Chapter 32 for obtaining consent for the medical \ntreatment of clients in the absence of the primary caregiver.\n• For obtaining physician signatures for all telephone o
# ...

# %%
text_chunks[51]
# Out:
# Document(page_content='Provider Responsibilities . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 39\n1.7.15 Private Duty Nursing (PDN) Providers  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .  . . 39\n1.7.16 Certified Respiratory Care Practitioner (CRCP) Services . . . . . . . . . . . . . . . . . . . . . . . . . . . . 40', metadata={'source': '/content/drive/MyDrive/ColabStuff/TMPPMfiles/2023-07-TMPPM.pdf', 'page': 8})

# %%
import pandas as pd

# Create a dataframe with the text chunk data.
df = pd.DataFrame.from_dict(text_chunks)


# Save the dataframe to a CSV file. use below with final version
# df.to_csv('/content/drive/MyDrive/ColabStuff/TMPPMfiles/TMPPM_text_chunks.csv')

# %% [markdown]
# rename the columns of the dataframe (pending rename the index column)

# %%
df=df.rename(columns={0:"chunk", 1:"metadata"})

# %% [markdown]
# keep the value/content only portion in the chunck, removes the key

# %%
df['chunk']=df['chunk'].str[1]

# %% [markdown]
# same for the metadata column, keep value only

# %%
df['metadata']=df['metadata'].str[1]

# %% [markdown]
# pending parse out the object into individual columns

# %%
df['metadata']
# Out:
# 0        {'source': '/content/drive/MyDrive/ColabStuff/...
# 1        {'source': '/content/drive/MyDrive/ColabStuff/...
# 2        {'source': '/content/drive/MyDrive/ColabStuff/...
# 3        {'source': '/content/drive/MyDrive/ColabStuff/...
# 4        {'source': '/content/drive/MyDrive/ColabStuff/...
#                                ...
# 12473    {'source': '/content/drive/MyDrive/ColabStuff/...
# 12474    {'source': '/content/drive/MyDrive/ColabStuff/...
# 12475    {'source': '/content/drive/MyDrive/ColabStuff/...
# 12476    {'source': '/content/drive/MyDrive/ColabStuff/...
# 12477    {'source': '/content/drive/MyDrive/ColabStuff/...
# Name: metadata, Length: 12478, dtype: object

# %% [markdown]
# download as csv, then later upload directly to hugging face project dataset using the "add file" from hugging face ui.  pending upload directly to hugging face repo.

# %%
# Save the dataframe to a CSV file.
df.to_csv('/content/drive/MyDrive/ColabStuff/TMPPMfiles/TMPPM_text_chunks.csv')

# then upload the file to HuggingFace DataSet

# %%
# connect to huggingface
from huggingface_hub import notebook_login
notebook_login()

# %%
# # original prep data for embed and index, below will create chunks from TMHP docs file
from datasets import load_dataset

data = load_dataset(
    'stevenbowler/TMHP_Procedures',
    split='train'
)
data
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset({
#     features: ['Unnamed: 0', 'chunk', 'metadata'],
#     num_rows: 12478
# })

# %% [markdown]
# Alternate method to generate  (currently commented out, skip)

# %%
# import os
# import getpass

# os.environ['OPENAI_API_KEY'] = getpass.getpass('openaikey: ')
# Out:
# openaikey: ··········

# %%
# from langchain.vectorstores import FAISS
# from langchain.embeddings.openai import OpenAIEmbeddings

# faiss_index = FAISS.from_documents(pages, OpenAIEmbeddings())
# docs = faiss_index.similarity_search("How will the community be engaged?", k=2)
# for doc in docs:
#     print(str(doc.metadata["page"]) + ":", doc.page_content[:300])

# %% [markdown]
# SB: attempt #1 Create chunks from TMHP document

# %%
# # create text string from the pdf file   WORKS
# from pypdf import PdfReader

# reader = PdfReader('/content/drive/MyDrive/ColabStuff/2023-07-TMPPM.pdf')
# text = ""
# for page in reader.pages:
#     text += page.extract_text() + "\n"

# text

# %% [markdown]
# os.environ['PINECONE_API_KEY'] = getpass.getpass('PineCone key: ')
# os.environ['PINECONE_ENVIRONMENT'] = getpass.getpass('PineCone Env: ')

# %%
import os
import getpass

# %%
pinecone_api_key=os.environ['PINECONE_API_KEY'] = getpass.getpass('PineCone Key: ')
pinecone_environment=os.environ['PINECONE_ENVIRONMENT'] = getpass.getpass('PineCone Env: ')
# Out:
# PineCone Key: ··········
# PineCone Env: ··········

# %% [markdown]
# ## Building the Vector Index
#
# We now need to use the embedding pipeline to build our embeddings and store them in a Pinecone vector index. To begin we'll initialize our index, for this we'll need a [free Pinecone API key](https://app.pinecone.io/).

# %%
from pydantic import env_settings
import os
import pinecone

# load env variables from Google Drive
# !source /content/drive/MyDrive/ColabStuff/env_vars.sh
# env_vars = !source /content/drive/MyDrive/ColabStuff/env_vars.sh

# get API key from app.pinecone.io and environment from console
pinecone.init(
    # api_key=os.environ.get('PINECONE_API_KEY') or 'PINECONE_API_KEY',
    # environment=os.environ.get('PINECONE_ENVIRONMENT') or 'PINECONE_ENV'
    api_key=pinecone_api_key,
    environment=pinecone_environment
)

# %% [markdown]
# Now we initialize the index.

# %%
import time

index_name = 'llama-2-rag'

if index_name not in pinecone.list_indexes():
    pinecone.create_index(
        index_name,
        dimension=len(embeddings[0]),
        metric='cosine'
    )
    # wait for index to finish initialization
    while not pinecone.describe_index(index_name).status['ready']:
        time.sleep(1)

# %% [markdown]
# Now we connect to the index:

# %%
index = pinecone.Index(index_name)
index.describe_index_stats()
# Out:
# {'dimension': 384,
#  'index_fullness': 0.17316,
#  'namespaces': {'': {'vector_count': 17316}},
#  'total_vector_count': 17316}

# %%
# # add dataframe to dataset
# from datasets import Dataset
# dataset = Dataset.from_pandas(dataframe)

# Dataset({
#    features: ['foo'],
#    num_rows: 2
# })

# %%
# # import file to dataset
# from datasets import load_dataset

# file_location = '/content/drive/MyDrive/ColabStuff/TMPPMfiles'

# data = load_dataset(
#     path=file_location,
#     split='train'
# )
# data

# %% [markdown]
# We will embed and index the documents like so:

# %%
data = data.to_pandas()

batch_size = 32

for i in range(0, len(data), batch_size):
    i_end = min(len(data), i+batch_size)
    batch = data.iloc[i:i_end]
    ids = [f"{x['Unnamed: 0']}" for i, x in batch.iterrows()]
    texts = [x['chunk'] for i, x in batch.iterrows()]
    embeds = embed_model.embed_documents(texts)
    # get metadata to store in Pinecone
    metadata = [
        {'metadata': x['metadata']} for i, x in batch.iterrows()
    ]
    # add to Pinecone
    index.upsert(vectors=zip(ids, embeds, metadata))

# %%
index.describe_index_stats()
# Out:
# {'dimension': 384,
#  'index_fullness': 0.17316,
#  'namespaces': {'': {'vector_count': 17316}},
#  'total_vector_count': 17316}

# %% [markdown]
# ## Initializing the Hugging Face Pipeline

# %% [markdown]
# SB: This for the initial setup and creation of the model, which, in non-quantized format can be stored in HuggingFace for future reference, to speed up model loading and testing for future runs.
#
# Inital setup:
# The first thing we need to do is initialize a `text-generation` pipeline with Hugging Face transformers. The Pipeline requires three things that we must initialize first, those are:
#
# * A LLM, in this case it will be `meta-llama/Llama-2-7b-chat-hf`.
#
# * The respective tokenizer for the model.
#
# We'll explain these as we get to them, let's begin with our model.
#
# We initialize the model and move it to our CUDA-enabled GPU. Using Colab this can take 5-10 minutes to download and initialize the model.

# %%
import os
import getpass

# %%
# get the HuggingFace API key
hf_auth=os.environ['HUGGING_FACE_API'] = getpass.getpass('HuggingFace API Key: ')
# Out:
# HuggingFace API Key: ··········

# %%
# this is the original w llama2 model
import torch  # added for gptq quantizer changes
from torch import cuda, bfloat16
import transformers

model_id = 'meta-llama/Llama-2-7b-chat-hf'

device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'

# set quantization configuration to load large model with less GPU memory
# this requires the `bitsandbytes` library
bnb_config = transformers.BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=bfloat16
)

# begin initializing HF items, need auth token for these
# hf_auth = ''
model_config = transformers.AutoConfig.from_pretrained(
    model_id,
    use_auth_token=hf_auth
)

model = transformers.AutoModelForCausalLM.from_pretrained(
    model_id,
    trust_remote_code=True,
    config=model_config,
    #quantization_config=bnb_config,  # comment out to create Hugging Face compatible version
    device_map='auto',
    use_auth_token=hf_auth
)
# model.eval()      # put model in evaluation mode
print(f"Model loaded on {device}")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/configuration_auto.py:995: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py:460: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Model loaded on cuda:0
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:373: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(

# %% [markdown]
# Save non quantized version of LLaMa2 7B with PineCone Vector DB TMHP version to Google drive, then upload to HuggingFace, since quantized versions can not be saved.  Remember: in previous step, when creating the model, need to comment out the quantization.

# %%
# model.save_pretrained('/content/drive/MyDrive/ColabStuff/TMPPMfiles/TMHP-ChatBot-1.pt')  # save non-quantized

from transformers import AutoModel

# Push the model to an organization with the name "my-finetuned-bert".
model.push_to_hub("stevenbowler/MedChatBot")
# Out:
# CommitInfo(commit_url='https://huggingface.co/stevenbowler/MedChatBot/commit/9cc084ba04b6bb6c5a245a2c3b2aac4f8f587e84', commit_message='Upload LlamaForCausalLM', commit_description='', oid='9cc084ba04b6bb6c5a245a2c3b2aac4f8f587e84', pr_url=None, pr_revision=None, pr_num=None)

# %%
tokenizer.push_to_hub("stevenbowler/MedChatBot")
# Out:
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/stevenbowler/MedChatBot/commit/0b34b0c6a0af7603a42a954ac1d40aaea77e7934', commit_message='Upload tokenizer', commit_description='', oid='0b34b0c6a0af7603a42a954ac1d40aaea77e7934', pr_url=None, pr_revision=None, pr_num=None)

# %%
tokenizer = AutoTokenizer.from_pretrained(save_directory)
model = AutoModel.from_pretrained(save_directory, from_tf=True)

# %% [markdown]
# # GPTQ quantizer
# try out the gptq 8bit quantizer to later try to upload gptq model to HuggingFace

# %%
# !pip install auto-gptq
# !pip install --upgrade optimum
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 28.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.6/380.6 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# This is one way to quantize the model in 4 bits, then push to HuggingFace

# %%
# !which transformers

# %%
# !export PYTHONPATH=$PYTHONPATH:/path/to/transformers

# %%
#!pip list

# %% [markdown]
# Load the non-quantized model

# %%
# get dimensions of parameters in the checkpoint
#torch.nn.Module.state_dict().keys()

# Create an instance of the torch.nn.Module class
model_dimensions = torch.nn.Module()

# Get the dimensions of the parameters in the checkpoint
keys = model_dimensions.state_dict().keys()

# %%
keys
# Out:
# odict_keys([])

# %%
import transformers

# # Load the model and the checkpoint
# model = transformers.AutoModelForCausalLM.from_pretrained("stevenbowler/MedChatBot")
# checkpoint = transformers.load_pretrained_model("stevenbowler/MedChatBot")

# # Resize the parameters in the model to match the dimensions of the parameters in the checkpoint
# model.resize_model(checkpoint)

# Save the model
torch.save(model, "model.pt")
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# <ipython-input-19-7537b37b7bba> in <cell line: 11>()
#       9
#      10 # Save the model
# ---> 11 torch.save(model, "model.pt")
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     439     if _use_new_zipfile_serialization:
#     440         with _open_zipfile_writer(f) as opened_zipfile:
# --> 441             _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     442             return
#     443     else:
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol)
#     651     pickler = pickle_module.Pickler(data_buf, protocol=pickle_protocol)
#     652     pickler.persistent_id = persistent_id
# --> 653     pickler.dump(obj)
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from optimum.gptq import GPTQQuantizer, load_quantized_model
import torch
model_name = "stevenbowler/MedChatBot"
# tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16)

quantizer = GPTQQuantizer(bits=4, dataset="c4", block_name_to_quantize = "model.decoder.layers", model_seqlen = 2048)
quantized_model = quantizer.quantize_model(model, tokenizer)

# %%
from transformers import AutoTokenizer, DistilBertTokenizer

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from optimum.gptq import GPTQQuantizer, load_quantized_model

# %%
tokenizer_model_name = 'meta-llama/Llama-2-7b-chat-hf'
tokenizer = AutoTokenizer.from_pretrained(tokenizer_model_name, use_auth_token=hf_auth)
quantizer = GPTQQuantizer(bits=4, dataset="c4", block_name_to_quantize = "model.decoder.layers", model_seqlen = 2048)
quantized_model = quantizer.quantize_model(model, tokenizer)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:631: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-24e61c2eedaa> in <cell line: 4>()
#       2 tokenizer = AutoTokenizer.from_pretrained(tokenizer_model_name, use_auth_token=hf_auth)
#       3 quantizer = GPTQQuantizer(bits=4, dataset="c4", block_name_to_quantize = "model.decoder.layers", model_seqlen = 2048)
# ----> 4 quantized_model = quantizer.quantize_model(model, tokenizer)
#
# NameError: name 'model' is not defined

# %% [markdown]
# Import the MedChatBot, quantize it and prep for chat

# %%
# !pip install torch

# %%
from transformers import torch
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-881dcac13321> in <cell line: 1>()
# ----> 1 from transformers import torch
#
# ImportError: cannot import name 'torch' from 'transformers' (/usr/local/lib/python3.10/dist-packages/transformers/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import torch
from torch import cuda, bfloat16
import transformers

model_id = 'stevenbowler/MedChatBot'

device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'

# set quantization configuration to load large model with less GPU memory
# this requires the `bitsandbytes` library
bnb_config = transformers.BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=bfloat16
)

# begin initializing HF items, need auth token for these
# hf_auth = ''
model_config = transformers.AutoConfig.from_pretrained(
    model_id,
    use_auth_token=hf_auth
)

model = transformers.AutoModelForCausalLM.from_pretrained(
    model_id,
    trust_remote_code=True,
    config=model_config,
    # quantization_config=bnb_config,  # comment out to create Hugging Face compatible version
    device_map='auto',
    use_auth_token=hf_auth,
    torch_dtype=torch.float16,
    # bnb_4bit_compute_dtype=torch.float32,
    # load_in_8bit_fp32_cpu_offload=True,
    offload_folder="/content/drive/MyDrive/ColabStuf/GPTQoffload"

)
model.eval()
print(f"Model loaded on {device}")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-11-708eebdec93a> in <cell line: 25>()
#      23 )
#      24
# ---> 25 model = transformers.AutoModelForCausalLM.from_pretrained(
#      26     model_id,
#      27     trust_remote_code=True,
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     514         elif type(config) in cls._model_mapping.keys():
#     515             model_class = _get_model_class(config, cls._model_mapping)
# --> 516             return model_class.from_pretrained(
#     517                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     518             )
#
# ...

# %% [markdown]
# SB add model fine tuning

# %%
hf_auth
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-20c97e878354> in <cell line: 1>()
# ----> 1 hf_auth
#
# NameError: name 'hf_auth' is not defined

# %%
# install fine tuner
# !pip install autotrain-advanced
# !pip install huggingface_hub

# %% [markdown]
# SB: Setup auto-trainer for Google Colab

# %%
# !autotrain setup --update-torch
# Out:
# > INFO    Installing latest transformers@main
# > INFO    Successfully installed latest transformers
# > INFO    Installing latest peft@main
# > INFO    Successfully installed latest peft
# > INFO    Installing latest diffusers@main
# > INFO    Successfully installed latest diffusers
# > INFO    Installing latest trl@main
# > INFO    Successfully installed latest trl
# > INFO    Installing latest xformers
# > INFO    Successfully installed latest xformers
# > INFO    Installing latest PyTorch
# > INFO    Successfully installed latest PyTorch

# %% [markdown]
# SB:HuggingFace credentials:

# %%
from huggingface_hub import notebook_login
notebook_login()

# %% [markdown]
# --- Fine Tuning Command
#
# !autotrain llm --train --project_name 'finetunellama2' --model TinyPixel/Llama-2-7B-bf16-sharded --data_path stevenbowler/TMHP_Procedures  --text_column text --use_peft --use_int4 --learning_rate 2e-4 --train_batch_size 2 --num_train_epochs 3 --trainer sft --model_max_length 2048 --push_to_hub --repo_id stevenbowler/FineTuneLLaMa2 --block_size 2048 > training.log

# %%
# !autotrain llm --train --project_name 'FineTuneLLaMa2' --model TinyPixel/Llama-2-7B-bf16-sharded --data_path timdettmers/openassistant-guanaco  --text_column text --use_peft --use_int4 --learning_rate 2e-4 --train_batch_size 2 --num_train_epochs 3 --trainer sft --model_max_length 2048 --push_to_hub --repo_id stevenbowler/FineTuneLLaMa2 --block_size 2048 > training.log
# Out:
# > INFO    Running LLM
# > INFO    Params: Namespace(version=False, train=True, deploy=False, inference=False, data_path='stevenbowler/TMHP_Procedures', train_split='train', valid_split=None, text_column='text', model='TinyPixel/Llama-2-7B-bf16-sharded', learning_rate=0.0002, num_train_epochs=3, train_batch_size=2, warmup_ratio=0.1, gradient_accumulation_steps=1, optimizer='adamw_torch', scheduler='linear', weight_decay=0.0, max_grad_norm=1.0, seed=42, add_eos_token=False, block_size=2048, use_peft=True, lora_r=16, lora_alpha=32, lora_dropout=0.05, logging_steps=-1, project_name='FineTuneLLaMa2', evaluation_strategy='epoch', save_total_limit=1, save_strategy='epoch', auto_find_batch_size=False, fp16=False, push_to_hub=True, use_int8=False, model_max_length=2048, repo_id='stevenbowler/FineTuneLLaMa2', use_int4=True, trainer='sft', target_modules=None, merge_adapter=False, token=None, backend='default', username=None, func=<function run_llm_command_factory at 0x7d83a5330790>)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# The pipeline requires a tokenizer which handles the translation of human readable plaintext to LLM readable token IDs. The Llama 2 13B models were trained using the Llama 2 13B tokenizer, which we initialize like so:

# %%
tokenizer = transformers.AutoTokenizer.from_pretrained(
    model_id,
    use_auth_token=hf_auth
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:631: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# ...

# %%
save_directory = '/content/drive/MyDrive/aColabTunedModel'
tokenizer.save_pretrained(save_directory)
model.save_pretrained(save_directory)

# %%
import transformers
AutoTokenizer = transformers.AutoTokenizer

# %%
from transformers import AutoModel

# %%
repo_id = 'stevenbowler/MedChatBot'
tokenizer = AutoTokenizer.from_pretrained(repo_id)
model = AutoModel.from_pretrained(repo_id)
# Out:
# ...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-fe6dd6151329> in <cell line: 3>()
#       1 repo_id = 'stevenbowler/MedChatBot'
#       2 tokenizer = AutoTokenizer.from_pretrained(repo_id)
# ----> 3 model = AutoModel.from_pretrained(repo_id)
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     514         elif type(config) in cls._model_mapping.keys():
#     515             model_class = _get_model_class(config, cls._model_mapping)
# --> 516             return model_class.from_pretrained(
#     517                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     518             )
#
# ...

# %% [markdown]
# Now we're ready to initialize the HF pipeline. There are a few additional parameters that we must define here. Comments explaining these have been included in the code.

# %%
generate_text = transformers.pipeline(
    model=model, tokenizer=tokenizer,
    return_full_text=True,  # langchain expects the full text
    task='text-generation',
    # we pass model parameters here too
    temperature=0.1,  # 'randomness' of outputs, 0.0 is the min and 1.0 the max
    max_new_tokens=512,  # mex number of tokens to generate in the output
    repetition_penalty=1.1  # without this output begins repeating
)

# %% [markdown]
# Confirm this is working:

# %%
res = generate_text("Explain to me the difference between nuclear fission and fusion.")
print(res[0]["generated_text"])
# Out:
# Explain to me the difference between nuclear fission and fusion. Unterscheidung between nuclear fission and fusion: Nuclear fission is a process in which an atomic nucleus splits into two or more smaller nuclei, releasing energy in the process. Nuclear fusion, on the other hand, is the process by which two or more atomic nuclei combine to form a single, heavier nucleus.
# Nuclear fission is a process where an atomic nucleus splits into two or more smaller nuclei, releasing energy in the process. This process typically occurs when an atom's nucleus is bombarded with a high-energy particle, such as a neutron. When this happens, the nucleus can become unstable and break apart into lighter elements, releasing a large amount of energy in the process.
# ...

# %% [markdown]
# Now to implement this in LangChain

# %%
from langchain.llms import HuggingFacePipeline

llm = HuggingFacePipeline(pipeline=generate_text)

# %%
llm(prompt="Explain to me the difference between nuclear fission and fusion.")
# Out:
# " Unterscheidung between nuclear fission and fusion: Nuclear fission is a process in which an atomic nucleus splits into two or more smaller nuclei, releasing energy in the process. Nuclear fusion, on the other hand, is the process by which two or more atomic nuclei combine to form a single, heavier nucleus.\nNuclear fission is a process where an atomic nucleus splits into two or more smaller nuclei, releasing energy in the process. This process typically occurs when an atom's nucleus is bombarded with a high-energy particle, such as a neutron. When this happens, the nucleus can become unstable and break apart into lighter elements, releasing a large amount of energy in the process.\nNuclear fusion, on the other hand, is the process by which two or more atomic nuclei combine to form a single, heavier nucleus. This process also releases energy, but it does so in a much more controlled and sustained manner than nuclear fission. In nuclear fusion, the nuclei of two atoms are brought tog
# ...

# %%
llm(prompt="how many volumes are there in the Texas Medicaid Provider Procedures Manual?")
# Out:
# "\n everybody knows that the manual is a comprehensive guide for healthcare providers who participate in the Texas Medicaid program. The manual provides detailed information on billing, coding, and coverage requirements for various medical services and procedures. It also includes information on fraud and abuse prevention, quality improvement initiatives, and other important topics related to Medicaid participation.\nThe number of volumes in the Texas Medicaid Provider Procedures Manual can vary depending on the edition. However, according to the Texas Health and Human Services Commission (HHSC), which publishes the manual, the most recent edition consists of 14 volumes. These volumes cover different aspects of Medicaid participation, including:\n1. Volume 1: Introduction and Program Overview\n2. Volume 2: Eligibility and Enrollment\n3. Volume 3: Benefits and Coverage\n4. Volume 4: Medical Services and Procedures\n5. Volume 5: Pharmacy Services\n6. Volume 6: Durable Medical Equipment
# ...

# %% [markdown]
# We still get the same output as we're not really doing anything differently here, but we have now added **Llama 2 13B Chat** to the LangChain library. Using this we can now begin using LangChain's advanced agent tooling, chains, etc, with **Llama 2**.

# %% [markdown]
# ## Initializing a RetrievalQA Chain

# %% [markdown]
# For **R**etrieval **A**ugmented **G**eneration (RAG) in LangChain we need to initialize either a `RetrievalQA` or `RetrievalQAWithSourcesChain` object. For both of these we need an `llm` (which we have initialized) and a Pinecone index — but initialized within a LangChain vector store object.
#
# Let's begin by initializing the LangChain vector store, we do it like so:

# %%
from langchain.vectorstores import Pinecone

text_field = 'text'  # field in metadata that contains text content

vectorstore = Pinecone(
    index, embed_model.embed_query, text_field
)

# %% [markdown]
# We can confirm this works like so:

# %%
query = 'what makes llama 2 special?'

vectorstore.similarity_search(
    query,  # the search query
    k=3  # returns top 3 most relevant chunks of text
)
# Out:
# [Document(page_content='Ricardo Lopez-Barquilla, Marc Shedroﬀ, Kelly Michelena, Allie Feinstein, Amit Sangani, Geeta\nChauhan,ChesterHu,CharltonGholson,AnjaKomlenovic,EissaJamil,BrandonSpence,Azadeh\nYazdan, Elisa Garcia Anzano, and Natascha Parks.\n•ChrisMarra,ChayaNayak,JacquelinePan,GeorgeOrlin,EdwardDowling,EstebanArcaute,Philomena Lobo, Eleonora Presani, and Logan Kerr, who provided helpful product and technical organization support.\n46\n•Armand Joulin, Edouard Grave, Guillaume Lample, and Timothee Lacroix, members of the original\nLlama team who helped get this work started.\n•Drew Hamlin, Chantal Mora, and Aran Mun, who gave us some design input on the ﬁgures in the\npaper.\n•Vijai Mohan for the discussions about RLHF that inspired our Figure 20, and his contribution to the\ninternal demo.\n•Earlyreviewersofthispaper,whohelpedusimproveitsquality,includingMikeLewis,JoellePineau,\nLaurens van der Maaten, Jason Weston, and Omer Levy.', metadata={'source': 'http://arxiv.org/pdf/2
# ...

# %% [markdown]
# Looks good! Now we can put our `vectorstore` and `llm` together to create our RAG pipeline.

# %%
from langchain.chains import RetrievalQA

rag_pipeline = RetrievalQA.from_chain_type(
    llm=llm, chain_type='stuff',
    retriever=vectorstore.as_retriever()
)

# %% [markdown]
# Let's begin asking questions! First let's try *without* RAG:

# %%
llm('what is so special about llama 2?')
# Out:
# '\n nobody knows.\n\nBut the llama 2 has a secret: it\'s actually a highly advanced AI language model, capable of generating human-like text based on the input it receives. It can be trained on large datasets of text data and can learn to mimic the style and tone of any author or genre of writing.\nThe llama 2 is a tool for writers, artists, and anyone who wants to create content that is both creative and accurate. With its advanced language generation capabilities, the llama 2 can help you generate ideas, write articles, create poetry, and even translate text from one language to another.\nBut don\'t just take our word for it! Here are some examples of what the llama 2 can do:\n* Generate a poem in the style of William Shakespeare:\nOde to a Llama\nIn days of old, when tales were told\nOf knights and dragons, brave and bold\nThere lived a creature, oh so fair\nA llama, with a woolly mane so rare\n\n* Write an article on the history of llamas:\nLlamas have been around for thousands o
# ...

# %% [markdown]
# Hmm, that's not what we meant... What if we use our RAG pipeline?

# %%
rag_pipeline('what is so special about llama 2?')
# Out:
# {'query': 'what is so special about llama 2?',
#  'result': ' Llama 2 is a collection of large language models (LLMs) that have been pretrained and fine-tuned for dialogue use cases. The models in Llama 2 outperform open-source chat models on most benchmarks and have been evaluated for helpfulness and safety. Unlike other publicly released pretrained LLMs, Llama 2 has been designed to be a suitable substitute for closed "product" LLMs like ChatGPT, BARD, and Claude.'}

# %% [markdown]
# This looks *much* better! Let's try some more.

# %%
llm('what safety measures were used in the development of llama 2?')
# Out:
# "\n\nI'm looking for information on how the developers of Llama 2 ensured the safety of their users during the development process. Specifically, I'm interested in knowing about any safety measures that were implemented to protect users from potential risks or hazards associated with the use of the platform.\n\nHere are some possible answers:\n\n1. The developers of Llama 2 conducted thorough risk assessments to identify and mitigate any potential safety risks associated with the platform. This included identifying potential hazards such as data breaches, cyber attacks, and other security risks, and implementing appropriate safeguards to prevent these risks from occurring.\n2. The platform was designed with user privacy and security in mind, and the developers implemented various measures to protect user data and ensure that it is not compromised. For example, the platform may have implemented encryption techniques to protect user data, or implemented strict access controls to limit 
# ...

# %% [markdown]
# Okay, it looks like the LLM with no RAG is less than ideal — let's stop embarassing the poor LLM and stick with RAG + LLM. Let's ask the same question to our RAG pipeline.

# %%
rag_pipeline('what safety measures were used in the development of llama 2?')
# Out:
# {'query': 'what safety measures were used in the development of llama 2?',
#  'result': ' The development of llama 2 included safety measures such as pre-training, fine-tuning, and model safety approaches. Additionally, the authors delayed the release of the 34B model due to a lack of time to sufficiently red team.'}

# %% [markdown]
# A reasonable answer from the RAG pipeline, but it doesn't contain much information — maybe we can ask more about this, like what is this _"red team"_ procedure that delayed the launch of the 34B model?

# %%
rag_pipeline('what red teaming procedures were followed for llama 2?')
# Out:
# {'query': 'what red teaming procedures were followed for llama 2?',
#  'result': " The paper describes the red teaming procedures used for Llama 2. These included creating prompts that might elicit unsafe or undesirable responses from the model, such as those based on sensitive topics or those that could potentially cause harm if the model were to respond inappropriately. The red teaming exercises were performed by a set of experts who evaluated the model's responses and provided feedback on its performance. The paper also mentions that multiple additional rounds of red teaming were performed over several months to measure the robustness of the model as it was released internally."}

# %% [markdown]
# Very interesting!

# %%
rag_pipeline('how does the performance of llama 2 compare to other local LLMs?')
# Out:
# {'query': 'how does the performance of llama 2 compare to other local LLMs?',
#  'result': ' The performance of llama 2 is compared to other local LLMs such as chinchilla and bard in the paper. Specifically, the authors report that llama 2 outperforms these other models on the series of helpfulness and safety benchmarks they tested. Additionally, the authors note that llama 2 appears to be on par with some of the closed-source models, at least on the human evaluations they performed.'}

# %% [markdown]
# ### additional tests using the THMP document

# %%
rag_pipeline('how many volumes are there in the Texas Medicaid Provider Procedures Manual?')
# Out:
# {'query': 'how many volumes are there in the Texas Medicaid Provider Procedures Manual?',
#  'result': " I don't know the exact number of volumes in the Texas Medicaid Provider Procedures Manual as it might be subject to change and I don't have access to the most up-to-date version of the manual. However, I can suggest some possible sources where you may be able to find this information, such as the official website of the Texas Medicaid program or by contacting the Texas Health and Human Services Commission directly."}
